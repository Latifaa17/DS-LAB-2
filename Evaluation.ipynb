# %%
# !pip install blanc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting blanc
#   Downloading blanc-0.3.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: nltk<4.0,>=3.1 in /usr/local/lib/python3.8/dist-packages (from blanc) (3.7)
# Requirement already satisfied: numpy<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from blanc) (1.21.6)
# Collecting transformers>=2.4.0
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 61.1 MB/s
# Requirement already satisfied: torch<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from blanc) (1.13.0+cu116)
# Requirement already satisfied: tqdm<5.0,>=4.27.0 in /usr/local/lib/python3.8/dist-packages (from blanc) (4.64.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from blanc) (1.7.3)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk<4.0,>=3.1->blanc) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk<4.0,>=3.1->blanc) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk<4.0,>=3.1->blanc) (1.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch<2.0,>=1.0->blanc) (4.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers>=2.4.0->blanc) (3.8.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 61.3 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers>=2.4.0->blanc) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers>=2.4.0->blanc) (2.23.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 72.4 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers>=2.4.0->blanc) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers>=2.4.0->blanc) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=2.4.0->blanc) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=2.4.0->blanc) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=2.4.0->blanc) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers>=2.4.0->blanc) (3.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers, blanc
# Successfully installed blanc-0.3.0 huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %%
from blanc import BlancHelp, BlancTune
import pandas as pd

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df = pd.read_csv('BART_Summaries.csv')
df.iloc[0]
# Out:
# Unnamed: 0                                                    0
# Lecture       Welcome back to Medical Engineering and today ...
# Summary       In the next two videos we want to talk about a...
# Name: 0, dtype: object

# %%
blanc_help = BlancHelp(device='cuda', inference_batch_size=16, show_progress_bar=False) #128
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
all_scores = []

for index, row in df.iterrows():
  score = blanc_help.eval_once(row["Lecture"], row['Summary'])
  print("score for record "+str(index)+" = "+str(score))
  all_scores.append(score)
# Out:
# score for record 0 = 0.19068203650336216
# score for record 1 = 0.17590618336886993
# score for record 2 = 0.14527445315724308
# score for record 3 = 0.1792411687745312
# score for record 4 = 0.1593724194880264
# score for record 5 = 0.18797512093987562
# score for record 6 = 0.19386574074074073
# score for record 7 = 0.19839395370807747
# score for record 8 = 0.18154761904761904
# score for record 9 = 0.13322435635472007
# score for record 10 = 0.11833398209420008
# score for record 11 = 0.1425914445133292
# score for record 12 = 0.1185121107266436

# %%
import statistics
statistics.mean(all_scores)
# Out:
# 0.1634554299551722
